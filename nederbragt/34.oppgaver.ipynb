# %% [markdown]
# <!-- File automatically generated using DocOnce (https://github.com/doconce/doconce/):
# doconce format ipynb 34.oppgaver.do.txt --userdef_environment_file=../userdef_environments.py --skip_inline_comments --encoding=utf-8 --language=Norwegian --ipynb_disable_mpl_inline --preprocess_include_subst -i WEEKNUMBER=34 WEEKFOLDER=./34 SEMESTER=H25 SEMESTERSIDE=https://www.uio.no/studier/emner/matnat/ibv/BIOS1101/h25 CANVASURL=https://uio.instructure.com/courses/54237 -DNORSK --ipynb_non_editable_text --without_solutions --without_answers --without_hints --output=../../pub/34/34.oppgaver.ipynb -->
#
# # BIOS1101 H25 oppgaver uke 34

# %% [markdown]
# ## Bli kjent med Jupyter Notebook
#
# Vi vil først øve oss på å jobbe med denne notebooken. Denne notebooken består av tekst blandet med Python kode, og steder du kan skrive din egen Python kode.
#
# **OBS**
#
# Skulle du dobbeltklikke på noe tekst, vil det se veldig annerledes ut. Hvis du for eksempel dobbeltklikker i *denne* tekstcellen, vil den se ut slik:

# %% [markdown]
# <!-- dom:FIGURE:[figures/tekst-som-markdown.png, alt="Skjembildet av hvordan denne cellen ser ut som vanlig markdown text"] Markdown versjonen av tekstcellen over. <div id="fig:md1"></div> -->
# <!-- begin figure -->
# <div id="fig:md1"></div>
#
# <img src="figures/tekst-som-markdown.png" alt="Skjembildet av hvordan denne cellen ser ut som vanlig markdown text"><p style="font-size: 0.9em"><i>Figur 1: Markdown versjonen av tekstcellen over.</i></p>
# <!-- end figure -->

# %% [markdown]
# ### Hva skjer?
#
# Teksten konverteres tilbake til det som kalles markdown-format. Vi snakker mer om markdown senere, men kort fortalt er det en måte å skrive enkel tekst og konvertere den til formatert tekst.
#
# Faktisk er disse tekstblokkene også celler i notebooken, men markdown-celler i stedet for Python (kode) celler.

# %% [markdown]
# ### Hvordan å fikse dette?
#
# Ved å selektere tekstcellen, å klikke på 'Run' knappen
# (eller presse både 'ctrl' tasten og 'enter' tasten)
# blir teksten formatert tilbake igjen.
# Prøv dette ut!

# %% [markdown]
# ## Jobbe med Python-kode i notebook
#
# I pensumboken er det mange steder med Python kode.
# Kapitlene er tilgjengelige både som PDF, samt som interaktive Jupyter notebooks.
# Hvis du jobber med boken som Jupyter Notebook, er resultatene fra all Python kode utelatt.
# Dermed skal du kjøre koden mens du jobber deg gjennom noteboken!
#
# Prøv dette nedenfor: kjør kodecellen.

# %%
print("Hei, verden!")

# %% [markdown]
# Fungerte det? Gratulerer!
#
# Nå skal du lage en ny kodecelle og skrive in et `print()` kommando
# som skriver ut navnet ditt.
#
# Bruk '+' knappen for å plassere en tom kodecelle
# herunder, og skriv `print()` kommandoet ditt inn i den nye cellen.

# %% [markdown]
# ## Ukens oppgaver

# %% [markdown]
# ## Oppgave 1: Rekkefølge av celler
#
# * Lag tre kodeceller med disse komandoer:

# %%
mitt_navn = "Alexander Rybak"

# %%
mitt_navn = "Bobbysocks"

# %%
print(mitt_navn)

# %% [markdown]
# * kjør cellene i forskjellige rekkefølger, f. eks.
#
#   * `1. - 2. - 3.`
#
#   * `2. - 3. - 1.`
#
#   * `3. - 3. - 3.`
#
# * Diskuter i par hva som skjer og om du forstår hvorfor

# %% [markdown]
# ## Oppgave 2: Finn feilen(e)
#
# Python programmene nedenfor inneholder en eller flere feil.
# Først skal du identifisere disse feilene *uten å kjøre programmet*,
# og deretter korrigere dem slik at programmene kjører uten feil.

# %% [markdown]
# **a)**
# Programmet med feilen(e):

# %% [markdown]
# ```Python
#         vekt_kg = 55
#         vekt_pund = 2.2 * vekt_kg
#         print(vekt_kg, "kilogram er det samme som", vekt pund 'Britiske pund')
# ```

# %% [markdown]
# Samme program i en ny kodecelle for deg å jobbe med:

# %%
vekt_kg = 55
vekt_pund = 2.2 * vekt_kg
print(vekt_kg, "kilogram er det samme som", vekt pund 'Britiske pund')

# %% [markdown]
# **b)**
# Programmet med feilen(e):

# %% [markdown]
# ```Python
#         lengde_m = 66
#         lengde_ft = 3.28 * lengde_m
#         print lengde_m, 'meter er det samme som", lengde_ft, fot")
# ```

# %% [markdown]
# Samme program i en ny kodecelle for deg å jobbe med:

# %%
lengde_m = 66
lengde_ft = 3.28 * lengde_m
print lengde_m, 'meter er det samme som", lengde_ft, fot")

# %% [markdown]
# **c)**
# Programmet med feilen(e):

# %% [markdown]
# ```Python
#         sekunder = 10**8
#         minuter = sekunder / 60
#         timer = minuter / 60
#         dager = timer / 60
#         aar = dager / 365.25
#         print(sekund, "sekunder er det samme som",, round(aar), 'aar')
# ```

# %% [markdown]
# Samme program i en ny kodecelle for deg å jobbe med:

# %%
sekunder = 10**8
minuter = sekunder / 60
timer = minuter / 60
dager = timer / 60
aar = dager / 365.25
print(sekund, "sekunder er det samme som",, round(aar), 'aar')

# %% [markdown]
# **d)**
# Hvilken av feilene er *ikke* av type `SyntaxError` (syntaks feil)?
# Hva slags feil ville du kalle det? Og hvordan oppdager man slike feil?

# %% [markdown]
# ## Oppgave 3: Refleksjon , og +
#
# Finn en medstudent og bruk 5 minutter til å skrive ned alle forskjeller
# mellom det å bruke `,` og `+` til å sette sammen strenger i `print` kommandoer

# %% [markdown]
# ## Oppgave 4: talltyper
#
# Finn en medstudent og diskuter hva som skrives til skjermen
# når de forskjellige kodelinjene nedenfor kjøres.

# %%
print(str(1) + str(int(2.0)))

print(int(str(int(str("45")))))

print(float("1.23"))

print(float(1.23))

print(float("1"))

print(float(1))

print(int("1.23"))

# %% [markdown]
# ## Oppgave 5: Forventet levealder
#
# Kan en nyfødt baby i Norge forvente å leve i en milliard ($10^9$) sekunder?
# Bruk Python for å beregninger for å svare på spørsmålet.

# %% [markdown]
# ## Flere Python oppgaver
#
# <div class="alert alert-block alert-info">
# Du finner flere oppgaver for å øve denne ukens nye Python-konsepter
# blant "Ekstraøvelser" for denne ukens kapittel.
# Se Canvas (under 'Pensum').
# </div>

# %% [markdown]
# ## Oppgave 6: Volum av en celle
#
# Man hører ofte at kroppene våre "består" av flere bakterieceller, enn våre egne celler.
# Men størrelsen på disse cellene er ganske forskjellige.
# Celler varierer veldig i størrelse, fra nevroner som strekker seg flere meter,
# til våre relativt små røde blodlegemer på mindre enn 10 $\mu$m.
#
# Radiusen på en menneskelig kinncelle er omtrent 50 $\mu$m,
# mens en bakteriecelle ikke er større enn 5 $\mu$m.
# Et vanlig estimat er en 100 ganger forskjell i radius,
# det vil si at radiusen til en bakteriecelle er 0,5 mikrometer ($\mu$m),
# og vi vil bruke den til denne øvelsen.
#
# I denne øvelsen skal vi lage et Python program som skal svare på dette spørsmålet:
#
# > Hvor mange bakterieceller ville ha samme volum som en kinncelle?
#
# Svarene på spørsmålene nedenfor skal
#
# * bruke variabler med fornuftige navn
#
# * være en full setning, og skrives ut på denne måten:

# %% [markdown]
# ```Python
#         svar = # legg til svaret her
#         print(svar)
# ```

# %% [markdown]
# **OBS** Ikke rund av tallene som regnes ut eller skrives ut underveis
# for noen av deloppgavene!

# %% [markdown]
# **a)**
# Skriv et Python-program som beregner volumet til en gjennomsnittlig menneskelig kinncelle,
# og skriver den ut.
# Volumet til en kule er gitt av formelen $\frac{4}{3}*\pi* radius^3$.

# %% [markdown]
# **b)**
# Skriv et program som beregner størrelsen på den gjennomsnittlige bakteriecellen,
# og skriver den ut.

# %% [markdown]
# **c)**
# Lag nå et samlet program som beregner mengden bakterieceller som til sammen
# har samme volum som en gjennomsnittlig menneskelig kinncelle.
# Dette siste programmet skal altså ha alle beregningene fra de forrige deloppgavene.

# %% [markdown]
# **d)**
# Kan du forklare svaret du fikk gitt den 100-ganger forskjellen i radius?

# %% [markdown]
# **e)**
# For hver av variablene du brukte, beskriv av hvilken type den er.
