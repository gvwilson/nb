# %% [markdown]
# <!-- File automatically generated using DocOnce (https://github.com/doconce/doconce/):
# doconce format ipynb øvingsoppgaver.34.do.txt --userdef_environment_file=../userdef_environments.py --skip_inline_comments --encoding=utf-8 --language=Norwegian --ipynb_disable_mpl_inline -DUKESNOTEBOOK --preprocess_include_subst -i WEEKNUMBER=34 WEEKFOLDER=./34 SEMESTER=H25 SEMESTERSIDE=https://www.uio.no/studier/emner/matnat/ibv/BIOS1101/h25 CANVASURL=https://uio.instructure.com/courses/54237 --ipynb_non_editable_text --without_solutions --without_answers --without_hints --output=../../pub/34/øvingsoppgaver.34.ipynb -->
#
# # Øvingsoppgaver uke 34
#
# Dette er mengdetreningsøvelser for de som ønsker
# å øve med Python begreper og konstrukter.
# Vi anbefaler at du forsøker å løse oppgavene
# i notebooken `34.øvingsoppgaver.ipynb` først selv,
# og deretter sammenligne med løsningene som ligger i notebooken
# `34.øvingsoppgaver-løsning.ipynb`.
#
# <!-- Trix exercise 1.02 -->

# %% [markdown]
# ## Oppgave 1: Printing in Python
#
# Write a Python program that will produce this output:

# %%
#
# Out:
# This is my sentence

# %% [markdown]
# <!-- <https://swcarpentry.github.io/python-novice-gapminder/02-variables/> -->

# %% [markdown]
# ## Oppgave 2: variables
#
# What is the final value of `position` in the program below? (Try to predict the
# value without running the program, then check your prediction.)

# %%
initial = "left"
position = initial
initial = "right"

# %% [markdown]
# <!-- <https://swcarpentry.github.io/python-novice-gapminder/03-types-conversion/> -->

# %% [markdown]
# ## Oppgave 3: variables and types
#
# What type of value is `4`? And `3.4`? How can you find out?

# %% [markdown]
# <!-- Trix exercise 1.04 -->

# %% [markdown]
# ## Oppgave 4: Changing variables

# %% [markdown]
# **a)**
# Write a Python program that will print the sentence "Hello world".

# %% [markdown]
# **b)**
# Now make a variable called `age` which has a value of `4`

# %% [markdown]
# **c)**
# Print the value of the `age` variable. Write in a full sentence.

# %% [markdown]
# **d)**
# Write the following as a comment in the program: "Now we will change the value of the variable age"

# %% [markdown]
# **e)**
# Now put everything you have done in the previous subexercises all together into one cell. In addition, change the value of the variable `age` to your own age. Finally, print a full sentence with the new value of the `age` variable.

# %% [markdown]
# <!-- Trix exercise 1.06 -->

# %% [markdown]
# ## Oppgave 5: Summing whole numbers
#
# Make two variables called `a` and `b`. Assign the values `4` and `5` to each of the variables. Print out the sum of the variables.

# %% [markdown]
# <!-- Trix exercise 1.07 -->

# %% [markdown]
# ## Oppgave 6: Area of a rectangle
#
# Make two variables, one called `width` and one called `height`. Decide for yourself the values of each. Print out the values of these variables. Then, make a third variable for the area of the rectangle (this will be the value of `width` multiplied by the value of `height`). Print the area of the rectangle, making sure the output is in a full sentence.

# %% [markdown]
# ## Oppgave 7: Find mistakes in the program
#
# You have the following program:

# %%
length = 3
volume = length * width * height

print("Volume is:" volume)

# %% [markdown]
# Find mistakes in the program and correct them.

# %% [markdown]
# ## Oppgave 8: Hva skjer?

# %% [markdown]
# Under følger tre kodesnutter. For hver av dem, svar på følgende spørsmål:
# * Er dette lovlig kode?
#
# * Hva skjer når vi prøver å kjøre programsnuttene hver for seg?

# %%
a = 10
print("var a er av type", type(a))
b = "hei!"
print(type(b))
c = str(a) + b
print(c)

# %%
print(a)
print(b)
print(a * b)

# %%
print("ACGT" * 10)

# %% [markdown]
# ## Oppgave 9: Fix the error
#
# These exercises are about discovering errors in a program
# and rewriting the program to avoid them.

# %% [markdown]
# Rewrite this program so that it runs without any errors.

# %%
conc1 = 6
v1 = 10
v2 = 4

conc2 = (conc1*v1)/v2

print("The final concentration is: " + conc2)

# %% [markdown]
# ## Oppgave 10: division
#
# Look at the following program, and try and predict what you think the value of c is. Check your answer by running the program in Python (but guess first!)

# %%
a = 1
b = 4

c = a / b * 3

print(c)

# %% [markdown]
# <!-- after <https://swcarpentry.github.io/python-novice-gapminder/04-built-in> -->

# %% [markdown]
# ## Oppgave 11: What happens when
#
# * Explain in simple terms the order of operations in the following program:
#
#     * when does the addition happen
#
#     * when does the subtraction happen
#
#     * when is each function called, etc.
#
# * What is the final value of `radiance`?

# %%
radiance = 1.0
radiance = max(2.1, 2.0 + min(radiance, 1.1 * radiance - 0.5))

# %% [markdown]
# ## Oppgave 12: Shopping
#
# This programme needs to calculate the total amount a customer needs to pay after shopping.
#
# The goods that are available for shopping are bread, milk, cheese and yogurt.
#
# The prices for different goods are:
# Bread: 20 kr
# Milk: 15 kr
# Cheese: 40 kr
# Yogurt: 12 kr.
#
# The customer wants to buy 2 bread, 1 milk, 1 cheese and 3 yogurt. Make a programme that calculates how much this customer needs to pay in kr.

# %% [markdown]
# ## Oppgave 13: Type, variable, value, function
#
# Given this Python program:

# %%
name = "Darwin"
print(name)
print(type(name))
my_number = int(1.0)
print(type(my_number))

# %% [markdown]
# Connect each time in the table with the correct term from the list below:
#
# * assignment statement
#
# * function call
#
# * type
#
# * value of type `int`
#
# * value of type `str`
#
# * variable
#
# <table class="dotable" border="1">
# <thead>
# <tr><th align="center">         This         </th> <th align="center">is a ...</th> </tr>
# </thead>
# <tbody>
# <tr><td align="center">   <code>str</code>                     </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>int</code>                     </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>int()</code>                   </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>name</code>                    </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>type(name)</code>              </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>print(name)</code>             </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>"Darwin"</code>                </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>1</code>                       </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>my_number</code>               </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>name = "Darwin"</code>         </td> <td align="center">               </td> </tr>
# <tr><td align="center">   <code>my_number = int(1.0)</code>    </td> <td align="center">               </td> </tr>
# </tbody>
# </table>
#
#
# <!-- <https://swcarpentry.github.io/python-novice-gapminder/02-variables/> -->

# %% [markdown]
# ## Oppgave 14: naming variables
#
# For the three variants of the same Python line below, which has the better variable names?
# Why?

# %% [markdown]
#         ts = m * 60 + s
#         tot_sec = min * 60 + sec
#         total_seconds = minutes * 60 + seconds

# %% [markdown]
# ## Oppgave 15: variables and types
#
# Finish this program (replacing the '___' parts) so that it gives the desired output.

# %% [markdown]
# **a)**

# %% [markdown]
# ```Python
#         result = 3.4 + 4
#         text = ___ result ___
#         print(text, 'is', type(text))
# ```

# %%
result = 3.4 + 4
text = ___ result ___
print(text, 'is', type(text))
# Out:
# 7.4 is <class 'str'>

# %% [markdown]
# **b)**

# %% [markdown]
# ```Python
#         a = "3.4"
#         b = 4
#         result = _____ + b
#         print(result, 'is', type(result))
# ```

# %%
a = "3.4"
b = 4
result = _____ + b
print(result, 'is', type(result))
# Out:
# 7.4 is <class 'float'>

# %% [markdown]
# ## Oppgave 16: Type conversion
#
# Which of the following will print `2.0`? Note: there may be more than one right
# answer.
# Think of the answer *before* you check using python.

# %%
first = 1.0
second = "1"
third = "1.1"

first + float(second)
float(second) + float(third)
first + int(third)
first + int(float(third))
int(first) + int(float(third))
2.0 * second

# %% [markdown]
# ## Oppgave 17: Use of functions
#
# Write Python statements to print out the answers to the following.
#
# 1. 3.8 rounded to the nearest integer.
#
# 2. 4.483847 rounded to one decimal place.
#
# 3. Convert 3.8 to an integer format using `int()`, assign the value to a variable, and print out it’s value.
#
# 4. Convert the answer to the previous question to a string and assign it to a new variable, print out the value.
#
# 5. Convert the answer to the previous question to a float and assign it to a new variable, print out the value.
#
# 6. Do you notice anything about the answer to the last question?
#
# 7. Take the square of the answer to the previous question, assign it to a new variable, print out the value.

# %% [markdown]
# ## Oppgave 18: Inches to centimeters
# <div id="ex:inch2cm"></div>
# <!-- keywords = basic; calculators; variables; length; -->

# %% [markdown]
# **a)**
# Imperial units, such as inches and pounds, are commonly used in the USA outside of scientific work. $1cm = 0.394 inches$. Write a calculator program that prints the amount of centimeters in 1 inch, in a full sentence.

# %% [markdown]
# **b)**
# Now write a program that converts from cm to inches.

# %% [markdown]
# ## Oppgave 19: Flat surface area
# <div id="ex:geometry1"></div>
# <!-- keywords = basic; variables; geometry; calculators -->

# %% [markdown]
# **a)**
# Store the two dimensions of a flat surface in the variables `width` and `length`. Allow the `width` to be 0.1m and the `length` to be 0.5m. Caluclate the surface area using the formula width * length and print it along with the text "The surface area in m^2 is: ". Try manipulating the input values to see how the surface area changes.

# %% [markdown]
# **b)**
# In molecular and cell biology the scale of meters is much too large to accurately describe events of interest. Instead, the unit of micrometers (or microns) is often used. A micrometer is one millionth of a meter, or simply $1*10^{-6} m$. Add a conversion step to your calculator that changes the final answer from meters to micrometers.
#
# Don't forget that surface areas are given as squares($m^2$), which must be taken into account when converting between units. E.g $1m = 100cm$ but $1m^2 = 10000cm^2$

# %% [markdown]
# ## Oppgave 20: float versus float()
#
# I ukens samkoding ble både `float` and `float()` vist.
# Men hva er egentlig forskjellen mellom `float` med og uten parentes bak?
#
# Bruk gjerne noen Python kommandoer eller program for å illustret svaret ditt.

# %% [markdown]
# ## Oppgave 21: Regnerekkefølgen
#
# Evaluer for hånd hva følgende Python kommando vil gi som resultat.

# %%
print(float("1" + "0")**2/2 +1)

# %% [markdown]
# Kjør deretter denne kodelinjen for å sjekke om du fikk det korrekte svaret.

# %% [markdown]
# ## Oppgave 22: Moles
# <div id="ex:moles"></div>
# <!-- keywords = basic; calculators; variables; -->

# %% [markdown]
# **a)**
# The mole is a unit used to denote an amount of small particles or molecules. It is equal to Avogadro's number. $1 mole = 6.022 * 10^{23}$ This means that 1 mole is equal to 6.02 x 10^23 particles of that substance.
#
# Write a program that converts any number of particles to the corresponding amount of moles. Print the answer in a full sentence.

# %% [markdown]
# **b)**
# Now write a calculator that takes a number of moles as input and prints how many molecules this equals.

# %% [markdown]
# ## Oppgave 23: Explain the program
#
# You have following program:

# %%
import numpy as np
cell_radius = 2
cell_volume = np.pi * cell_radius**2

print("Cell volume is:" cell_volume)

# %% [markdown]
# Without running the program, answer the following questions:
#
# * is this program valid
#
# * if not, explain why and correct the mistakes.
#
# After you have answered the question,
# run the prgram again to see if you were right.

# %% [markdown]
# ## Oppgave 24: pi
#
# Hvor mange desimaler har `pi` i Python? Hvordan finner du svaret?
